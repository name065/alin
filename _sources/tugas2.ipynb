# %% [markdown]
# # Aljabar Matriks
# **tidak mengerjakan tidak boleh masuk**
# - berikan penjelasan tentang apa itu matriks
# - operasi matriks
# - penjumlahan , perkalian, pengurangan transpose matriks
# - buat progam untuk perkalian matriks a dan b

# %% [markdown]
#  matriks a dan c

# %%
import numpy as np
a = np.array([[3,2,1],[1,2,3],[0,1,2]])
b = np.array([[1,2,3],[3,2,1],[0,1,2]])
c = np.array([[3,2],[2,3],[3,1]])
d = np.array([[4,5,6],[6,5,4],[0,1,2]])
e = a+b
f = 2*a
g = a@c
#print(d.shape)

#perkalian
a1 = a@b
a2 = b@c
h1 = a1@c
h2 = a@a2
# print(h1)
# print(h2)
# Out:
# (2, 2)

# %%
#transpose
c1 = c.transpose()
cova = c1@c
cova
# Out:
# array([[22, 15],
#        [15, 14]])

# %%
covb = c@c1
covb
# Out:
# array([[13, 12, 11],
#        [12, 13,  9],
#        [11,  9, 10]])
